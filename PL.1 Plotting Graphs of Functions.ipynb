# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x= np.arange(-10,11)
y= x**2

plt.plot(x,y)
plt.show()

# %%
x= np.arange(-10,11)
y= -x**2 + 100
plt.plot(x,y)
plt.show()

# %%
x= np.arange(0,11)
y= []

for i in x:
    y.append(math.exp(i))

plt.plot(x,y)
plt.show()

# %%
x= np.arange(0,11)
y= []

for i in x:
    y.append(-math.exp(i))

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-10,11)

y = []
for i in x:
    y.append(np.random.randint(1,10))

plt.step(x,y)
plt.show()

# %%
x = np.arange(-5,6)

f_x = []

for i in x:
    f_x.append(1/(1+math.e**-i))


plt.plot(x,f_x)
plt.show()

# %%
x = np.arange(-5,6)

f_x = []

for i in x:
    f_x.append(-1/(1+math.e**-i))


plt.plot(x,f_x)
plt.show()

# %%
x= np.arange(0,100000)
y= []

for i in x:
    y.append(math.sqrt(i))

plt.plot(x,y)
plt.show()

# %%
x= np.arange(0,100000)
y= []

for i in x:
    y.append(-math.sqrt(i))

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-100,101)

y = -abs(x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-100,101)

y = abs(x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-0,101)

y = np.log(x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-0,101)

y = -np.log(x)

plt.plot(x,y)
plt.show()

# %%
np.seterr(divide='ignore', invalid='ignore')
x= np.arange(-100,101)

y= 1/x

plt.plot(x,y)
plt.show()

# %%
x= np.arange(-100,101)

y= 1/-x

plt.plot(x,y)
plt.show()

# %%
x= np.arange(-50,51)

y= 1/(x**2)

plt.plot(x,y)
plt.show()

# %%
x= np.arange(-50,51)

y= 1/(-x**2)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-2,4)

y = x**2 - (2*x) + 2

plt.plot(x,y)
plt.show()

# %%
x =np.arange(-4,5)

y = 2*x +7

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-3,4)
y = -2*x

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-5,6)
y = x

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-5,6)
y = -x

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-5,6)
y = []
for i in x:
    y.append(7)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-3,4)

y = x**3 + x

plt.plot(x,y)
plt.show()

# %%
x = np.arange(-3, 4)

y = x+2

y2 = -0.5*x + 0.5

intersection = -0.5*x[2] + 0.5

plt.plot(x,y2, color = 'blue')
plt.plot(x,y)
plt.plot(x[2], intersection, 'o', color = 'red')
plt.show()

# %%
x = np.arange(-3,4)

y = 1/x
y2 = -1/x

plt.plot(x,y)
plt.plot(x, y2)
plt.show()

# %%
x = np.arange(-3,8.5)

y = []

for i in x:
    if i <= 3:
        y.append(i**2)
    elif i <= max(x):
        y.append(-2*i+15)
        
y1 = 2*x

y2 = 2*x +1

y3 = 2*x + 3

        
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()
